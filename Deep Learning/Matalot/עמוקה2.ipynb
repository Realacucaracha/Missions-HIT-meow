# %% [markdown]
# <h1 style="font-size: 80px; text-align: center; color: orange; font-family: Roboto; background: linear-gradient(132deg, rgb(200, 0, 0) 10.00%,  rgb(0, 0, 200) 40.00%, rgb(200, 200, 0) 60.00%,rgb(114, 6, 130) 100.00%);"
#
# ><i>שלום אהוד ולומט נראה שנפלתם ב: ב: C: בפחחחחחחחחחחחחחחח</i></h1>

# %% [markdown]
# <img src="https://media3.giphy.com/media/v1.Y2lkPTc5MGI3NjExMjIzcGhodDRyYWJtbTNucWw5Z2F3N3J4MHpoMWwwdXZha3puNGVrNiZlcD12MV9pbnRlcm5hbF9naWZfYnlfaWQmY3Q9Zw/Wrh8aL75aj4uZwuqta/giphy.webp" alt="Lamp" width="1920" height="1080">

# %% [markdown]
# קודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקודקוד

# %% [markdown]
# עוד דדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדקודדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדדד
